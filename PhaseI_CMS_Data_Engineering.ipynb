# %% [markdown]
# # Purpose
#
# The goal of this notebook is to pull down Centers for Medicare and Medicaid Services (CMS) data on hospital-level variables (e.g. the amount of times patients have serious falls in a given reporting period). This notebook focuses purely on the data wrangling and exploration steps of the Phase I analysis (please see the project's [README](README.md) for info on the Phases of this project). A separate notebook handles the more advanced modeling work for both Phases I and II.

# %% [markdown]
# # Background
#
# CMS collects are sorts of information on US hospitals as part of its role as a federally-managed insurance organization. I was inspired to think about modeling hospital outcomes by the news in early 2019 that CMS had mandated that all US hospital chargemaster data must be published online in machine-readable format on hospital websites. These tables provide the pre-insurance-negotiation prices for all procedures and consumables in a gvien hospital.
#
# Upon digging a bit into the chargemasters data I could find (and forking [a very helpful repo](https://github.com/vsoch/hospital-chargemaster) that had done a lot of the heavy lifting parsing many hospitals' chargemaster data), I determined that the cleaning process for those data (including discerning what procedures and consumables were equivalent items, due to the shorthand used to describe them in many instances) would be a bigger task, so  I split the work into two phases as described in the README.
#
# This notebook, as mentioned before, is concerned with Phase I's data collection steps.

# %% [markdown]
# # Pulling Data from CMS API
#
# The first step in this endeavor is to pull down as much relevant (and up to date) data as I can from [the CMS API covering hospitals](https://data.medicare.gov/data/hospital-compare).

# %%
# Package import

import json
import requests
import numpy as np
import pandas as pd
import plotly.express as px

# %%
# Pull app token to identify the analysis from private key file
# Note that data can be pulled without a token, but limits are put on the number of requests
# and the data stream is throttled

# I recommend that anyone attempting to reproduce this work generate their own token to do so

APP_TOKEN = pd.read_json("secure_keys/CMS_app_token.json").loc[0,'App Token']

# %%
def query_CMS(dataset_url, query_params={"$select": "*"}, app_token=APP_TOKEN):
    '''
    Queries the CMS API for a specific dataset and returns the data 
    from the query as a pandas DataFrame
    
    Inputs
    ------
    dataset_url: str. URL of the dataset being queried (CMS uses different source
        URLs for each dataset instead of exposing one big database via a single URL).
        Options for different dataset URLs can be found by exploring the documentation
        at https://data.medicare.gov/data/hospital-compare.
        
    query_params: dict. Represents the parameters that can be used to narrow queries from the API
        Don't explicitly include the app token in this, as it is added as part of execution of 
        this function. Also don't include a LIMIT parameter, as this will be calculated automatically
        and used to pull down the full dataset.
    
    
    Return
    ------
    pandas DataFrame with queried data and relevant metadata. 
        Will return None if query throws an error
'''

    # Query to figure out how many records there are and set LIMIT based on them
    r_count = requests.get(dataset_url, params={"$select": "COUNT(*)",
                                          "$$app_token": APP_TOKEN})
    num_rows = int(r_count.json()[0]['COUNT'])
    query_params["$limit"] = num_rows
    
    # Add the app token to avoid throttled queries
    query_params["$$app_token"] = app_token

    
    # Perform the main query
    r = requests.get(dataset_url, params=query_params)

    # Check that query didn't throw any errors
    if r.status_code == requests.codes.ok:
        print("Query successful!")
    else:
        print(f"Query failed with status code {r.status_code}")
        return None
    
        
    df = pd.DataFrame.from_dict(r.json())
        
    # Includes dataset last updated datetime as a column
    df['Dataset Last Updated'] = pd.to_datetime(r.headers['X-SODA2-Truth-Last-Modified'])
    
    return df

# %%
metadata = pd.read_csv('metadata.csv', encoding = 'latin-1')
metadata
# Out:
#                                         Dataset Name  \
# 0                                 Footnote Crosswalk
# 1                       Hospital General Information
# 2                Complications and Deaths - Hospital
# 3        Healthcare Associated Infections - Hospital
# 4            Hospital Readmissions Reduction Program
# 5  Medicare Spending Per Beneficiary Ð Hospital A...
# 6           Outpatient Imaging Efficiency - Hospital
# 7                 Patient survey (HCAHPS) - Hospital
# 8                     Structural Measures - Hospital
#
#                                     API Endpoint URL  \
# 0  https://data.medicare.gov/resource/sbph-xiia.json
# 1  https://data.medicare.gov/resource/rbry-mqwu.json
# 2  https://data.medicare.gov/resource/ukfj-tt6v.json
# 3  https://data.medicare.gov/resource/ppaw-hhm5.json
# 4  https://data.medicare.gov/resource/kac9-a9fp.json
# 5  https://data.medicare.gov/resource/8ckj-r4j6.json
# 6  https://data.medicare.gov/resource/72af-b2t9.json
# 7  https://data.medicare.gov/resource/rmgi-5fhi.json
# 8  https://data.medicare.gov/resource/w5ci-7egs.json
#
#                                          Description
# 0  List of footnotes referenced in many datasets ...
# 1  A list of all hospitals that have been registe...
# 2  Complications and deaths data provided by the ...
# 3  Hospital-provided data. These measures are dev...
# 4  Measures of frequency of patient readmissions ...
# 5  The Medicare Spending Per Beneficiary (MSPB) M...
# 6  Hospital-provided data about the use of medica...
# 7  A list of hospital ratings for the Hospital Co...
# 8  A list of hospitals and the structural measure...

# %%
footnote_mapping = query_CMS(metadata.loc[0, 'API Endpoint URL'])
footnote_mapping.head()
# Out:
# Query successful!
#   footnote                                      footnote_text  \
# 0        1  The number of cases/patients is too few to rep...
# 1        2  Data submitted were based on a sample of cases...
# 2        3  Results are based on a shorter time period tha...
# 3        4   Data suppressed by CMS for one or more quarters.
# 4        5  Results are not available for this reporting p...
#
#        Dataset Last Updated
# 0 2019-07-30 06:19:20+00:00
# 1 2019-07-30 06:19:20+00:00
# 2 2019-07-30 06:19:20+00:00
# 3 2019-07-30 06:19:20+00:00
# 4 2019-07-30 06:19:20+00:00

# %%
footnote_mapping.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30 entries, 0 to 29
# Data columns (total 3 columns):
# footnote                30 non-null object
# footnote_text           30 non-null object
# Dataset Last Updated    30 non-null datetime64[ns, UTC]
# dtypes: datetime64[ns, UTC](1), object(2)
# memory usage: 800.0+ bytes

# %%
def parse_footnote(footnote_ids, footnote_defs):
    '''
    As some of the CMS datasets provide the footnote ID number(s) 
    as a comma-delimited list of integers (unless there is only one or none),
    it is necessary to use the footnote definitions DataFrame to decode them
    if we need to understand any caveats present

    Inputs
    ------
    footnote_ids: single int as a str or list of comma-delimited ints as a str. The ID(s) of 
        relevant footnotes for a record

    footnote_defs: pandas DataFrame with mapping of footnote IDs to human-readable
        footnote text


    Returns
    -------
    pandas DataFrame of descriptions with each ID and its corresponding description text
    '''
    # Remove any spaces and make split into list based on commas
    # Single ID values will take form '1' -> ['1']
    footnote_ids = footnote_ids.replace(' ', '').split(',')

    return footnote_defs.loc[footnote_defs['footnote'].isin(footnote_ids),
                             ['footnote', 'footnote_text']]

# %%
gen_info = query_CMS(metadata.loc[1, 'API Endpoint URL'])
gen_info.sort_values('provider_id').head(20)
# Out:
# Query successful!
#      :@computed_region_csmy_5jwy :@computed_region_f3tr_pr43  \
# 3752                          29                        1551
# 1582                         NaN                         NaN
# 351                           29                        1584
# 1404                          29                        1539
# 101                           29                        1540
# 2200                          29                        1583
# 1043                         NaN                         NaN
# 3700                          29                        1636
# 1305                          29                        1583
# 1560                          29                        1498
# 5042                          29                          97
# 3683                          29                        1493
# 3738                          29                        1593
# 4201                          29                        1593
# 1824                          29                        1586
# 127                           29                         104
# 2929                          29                        1583
# 2631                          29                        1544
# 4970                          29                        1541
# 4095                          29                        1539
#
#      :@computed_region_nwen_78xc                          address        city  \
# 3752                        1551           1108 ROSS CLARK CIRCLE      DOTHAN
# 1582                         NaN       2505 U S HIGHWAY 431 NORTH        BOAZ
# 351                         1584              1701 VETERANS DRIVE    FLORENCE
# 1404                        1539                    702 N MAIN ST         OPP
# 101                         1540              101 HOSPITAL CIRCLE     LUVERNE
# 2200                        1583       50 MEDICAL PARK EAST DRIVE  BIRMINGHAM
# 1043                         NaN             200 MED CENTER DRIVE  FORT PAYNE
# 3700                        1636          1000 FIRST STREET NORTH   ALABASTER
# 1305                        1583  1720 UNIVERSITY BLVD, SUITE 500  BIRMINGHAM
# 1560                        1498     1300 SOUTH MONTGOMERY AVENUE   SHEFFIELD
# 5042                          97                 126 HOSPITAL AVE       OZARK
# 3683                        1493                 400 NORTHWOOD DR      CENTRE
# 3738                        1593        2105 EAST SOUTH BOULEVARD  MONTGOMERY
# 4201                        1593                 1725 PINE STREET  MONTGOMERY
# 1824                        1586           2000 PEPPERELL PARKWAY     OPELIKA
# 127                          104           1032 MAIN STREET SOUTH     WEDOWEE
# 2929                        1583            619 SOUTH 19TH STREET  BIRMINGHAM
# 2631                        1544              805 FRIENDSHIP ROAD   TALLASSEE
# 4970                        1541         1912 ALABAMA HIGHWAY 157     CULLMAN
# 4095                        1539     849 SOUTH THREE NOTCH STREET   ANDALUSIA
#
#      county_name effectiveness_of_care_national_comparison  \
# 3752     HOUSTON              Same as the national average
# 1582    MARSHALL                Above the national average
# 351   LAUDERDALE              Same as the national average
# 1404   COVINGTON                Below the national average
# 101     CRENSHAW              Same as the national average
# 2200   JEFFERSON                Below the national average
# 1043     DE KALB              Same as the national average
# 3700      SHELBY              Same as the national average
# 1305   JEFFERSON              Same as the national average
# 1560     COLBERT              Same as the national average
# 5042        DALE              Same as the national average
# 3683    CHEROKEE              Same as the national average
# 3738  MONTGOMERY              Same as the national average
# 4201  MONTGOMERY              Same as the national average
# 1824         LEE              Same as the national average
# 127     RANDOLPH              Same as the national average
# 2929   JEFFERSON              Same as the national average
# 2631      ELMORE              Same as the national average
# 4970     CULLMAN              Same as the national average
# 4095   COVINGTON              Same as the national average
#
#      effectiveness_of_care_national_comparison_footnote  \
# 3752                                                NaN
# 1582                                                NaN
# 351                                                 NaN
# 1404                                                NaN
# 101                                                 NaN
# 2200                                                NaN
# 1043                                                NaN
# 3700                                                NaN
# 1305                                                NaN
# 1560                                                NaN
# 5042                                                NaN
# 3683                                                NaN
# 3738                                                NaN
# 4201                                                NaN
# 1824                                                NaN
# 127                                                 NaN
# 2929                                                NaN
# 2631                                                NaN
# 4970                                                NaN
# 4095                                                NaN
#
#      efficient_use_of_medical_imaging_national_comparison  \
# 3752                       Same as the national average
# 1582                         Below the national average
# 351                          Below the national average
# 1404                                      Not Available
# 101                                       Not Available
# 2200                       Same as the national average
# 1043                       Same as the national average
# 3700                         Below the national average
# 1305                                      Not Available
# 1560                         Below the national average
# 5042                       Same as the national average
# 3683                                      Not Available
# 3738                       Same as the national average
# 4201                         Below the national average
# 1824                       Same as the national average
# 127                                       Not Available
# 2929                         Below the national average
# 2631                       Same as the national average
# 4970                       Same as the national average
# 4095                       Same as the national average
#
#      efficient_use_of_medical_imaging_national_comparison_footnote  ...  \
# 3752                                                NaN             ...
# 1582                                                NaN             ...
# 351                                                 NaN             ...
# 1404  Results are not available for this reporting p...             ...
# 101   Results are not available for this reporting p...             ...
# 2200                                                NaN             ...
# 1043                                                NaN             ...
# 3700                                                NaN             ...
# 1305  There are too few measures or measure groups r...             ...
# 1560                                                NaN             ...
# 5042                                                NaN             ...
# 3683  Results are not available for this reporting p...             ...
# 3738                                                NaN             ...
# 4201                                                NaN             ...
# 1824                                                NaN             ...
# 127   Results are not available for this reporting p...             ...
# 2929                                                NaN             ...
# 2631                                                NaN             ...
# 4970                                                NaN             ...
# 4095                                                NaN             ...
#
#       provider_id readmission_national_comparison  \
# 3752       010001      Below the national average
# 1582       010005      Below the national average
# 351        010006      Above the national average
# 1404       010007      Below the national average
# 101        010008      Above the national average
# 2200       010011      Below the national average
# 1043       010012      Below the national average
# 3700       010016      Above the national average
# 1305       010018                   Not Available
# 1560       010019      Below the national average
# 5042       010021    Same as the national average
# 3683       010022      Above the national average
# 3738       010023      Below the national average
# 4201       010024      Above the national average
# 1824       010029      Above the national average
# 127        010032    Same as the national average
# 2929       010033      Below the national average
# 2631       010034      Above the national average
# 4970       010035      Below the national average
# 4095       010036      Above the national average
#
#                readmission_national_comparison_footnote  \
# 3752                                                NaN
# 1582                                                NaN
# 351                                                 NaN
# 1404                                                NaN
# 101                                                 NaN
# 2200                                                NaN
# 1043                                                NaN
# 3700                                                NaN
# 1305  There are too few measures or measure groups r...
# 1560                                                NaN
# 5042                                                NaN
# 3683                                                NaN
# 3738                                                NaN
# 4201                                                NaN
# 1824                                                NaN
# 127                                                 NaN
# 2929                                                NaN
# 2631                                                NaN
# 4970                                                NaN
# 4095                                                NaN
#
#      safety_of_care_national_comparison  \
# 3752         Above the national average
# 1582         Below the national average
# 351          Above the national average
# 1404       Same as the national average
# 101                       Not Available
# 2200         Below the national average
# 1043         Above the national average
# 3700         Below the national average
# 1305                      Not Available
# 1560         Above the national average
# 5042                      Not Available
# 3683                      Not Available
# 3738         Above the national average
# 4201         Below the national average
# 1824         Above the national average
# 127                       Not Available
# 2929         Below the national average
# 2631                      Not Available
# 4970         Below the national average
# 4095         Above the national average
#
#             safety_of_care_national_comparison_footnote state  \
# 3752                                                NaN    AL
# 1582                                                NaN    AL
# 351                                                 NaN    AL
# 1404                                                NaN    AL
# 101   Results are not available for this reporting p...    AL
# 2200                                                NaN    AL
# 1043                                                NaN    AL
# 3700                                                NaN    AL
# 1305  Results are not available for this reporting p...    AL
# 1560                                                NaN    AL
# 5042  Results are not available for this reporting p...    AL
# 3683  Results are not available for this reporting p...    AL
# 3738                                                NaN    AL
# 4201                                                NaN    AL
# 1824                                                NaN    AL
# 127   Results are not available for this reporting p...    AL
# 2929                                                NaN    AL
# 2631  Results are not available for this reporting p...    AL
# 4970                                                NaN    AL
# 4095                                                NaN    AL
#
#      timeliness_of_care_national_comparison  \
# 3752             Above the national average
# 1582             Above the national average
# 351              Above the national average
# 1404             Above the national average
# 101              Above the national average
# 2200             Below the national average
# 1043             Above the national average
# 3700           Same as the national average
# 1305           Same as the national average
# 1560             Above the national average
# 5042             Above the national average
# 3683           Same as the national average
# 3738             Below the national average
# 4201             Below the national average
# 1824             Above the national average
# 127              Above the national average
# 2929             Below the national average
# 2631           Same as the national average
# 4970             Above the national average
# 4095             Above the national average
#
#      timeliness_of_care_national_comparison_footnote zip_code  \
# 3752                                             NaN    36301
# 1582                                             NaN    35957
# 351                                              NaN    35630
# 1404                                             NaN    36467
# 101                                              NaN    36049
# 2200                                             NaN    35235
# 1043                                             NaN    35968
# 3700                                             NaN    35007
# 1305                                             NaN    35233
# 1560                                             NaN    35660
# 5042                                             NaN    36360
# 3683                                             NaN    35960
# 3738                                             NaN    36116
# 4201                                             NaN    36106
# 1824                                             NaN    36801
# 127                                              NaN    36278
# 2929                                             NaN    35233
# 2631                                             NaN    36078
# 4970                                             NaN    35058
# 4095                                             NaN    36420
#
#           Dataset Last Updated
# 3752 2019-07-30 06:20:01+00:00
# 1582 2019-07-30 06:20:01+00:00
# 351  2019-07-30 06:20:01+00:00
# 1404 2019-07-30 06:20:01+00:00
# 101  2019-07-30 06:20:01+00:00
# 2200 2019-07-30 06:20:01+00:00
# 1043 2019-07-30 06:20:01+00:00
# 3700 2019-07-30 06:20:01+00:00
# 1305 2019-07-30 06:20:01+00:00
# 1560 2019-07-30 06:20:01+00:00
# 5042 2019-07-30 06:20:01+00:00
# 3683 2019-07-30 06:20:01+00:00
# 3738 2019-07-30 06:20:01+00:00
# 4201 2019-07-30 06:20:01+00:00
# 1824 2019-07-30 06:20:01+00:00
# 127  2019-07-30 06:20:01+00:00
# 2929 2019-07-30 06:20:01+00:00
# 2631 2019-07-30 06:20:01+00:00
# 4970 2019-07-30 06:20:01+00:00
# 4095 2019-07-30 06:20:01+00:00
#
# [20 rows x 37 columns]

# %%
gen_info.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5334 entries, 0 to 5333
# Data columns (total 37 columns):
# :@computed_region_csmy_5jwy                                      4879 non-null object
# :@computed_region_f3tr_pr43                                      4930 non-null object
# :@computed_region_nwen_78xc                                      4930 non-null object
# address                                                          5334 non-null object
# city                                                             5334 non-null object
# county_name                                                      5334 non-null object
# effectiveness_of_care_national_comparison                        5334 non-null object
# effectiveness_of_care_national_comparison_footnote               1514 non-null object
# efficient_use_of_medical_imaging_national_comparison             5334 non-null object
# efficient_use_of_medical_imaging_national_comparison_footnote    2292 non-null object
# emergency_services                                               5334 non-null bool
# hospital_name                                                    5334 non-null object
# hospital_overall_rating                                          5334 non-null object
# hospital_overall_rating_footnote                                 1753 non-null object
# hospital_ownership                                               5334 non-null object
# hospital_type                                                    5334 non-null object
# location                                                         4933 non-null object
# location_address                                                 5334 non-null object
# location_city                                                    5334 non-null object
# location_state                                                   5334 non-null object
# location_zip                                                     5334 non-null object
# meets_criteria_for_meaningful_use_of_ehrs                        3710 non-null object
# mortality_national_comparison                                    5334 non-null object
# mortality_national_comparison_footnote                           1951 non-null object
# patient_experience_national_comparison                           5334 non-null object
# patient_experience_national_comparison_footnote                  1911 non-null object
# phone_number                                                     5334 non-null object
# provider_id                                                      5334 non-null object
# readmission_national_comparison                                  5334 non-null object
# readmission_national_comparison_footnote                         1477 non-null object
# safety_of_care_national_comparison                               5334 non-null object
# safety_of_care_national_comparison_footnote                      2711 non-null object
# state                                                            5334 non-null object
# timeliness_of_care_national_comparison                           5334 non-null object
# timeliness_of_care_national_comparison_footnote                  1587 non-null object
# zip_code                                                         5334 non-null object
# Dataset Last Updated                                             5334 non-null datetime64[ns, UTC]
# dtypes: bool(1), datetime64[ns, UTC](1), object(35)
# memory usage: 1.5+ MB

# %%
# TODO: make Provider ID the index and re-order columns more logically
